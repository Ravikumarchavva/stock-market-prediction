# %%
from datetime import datetime
from lumibot.credentials import IS_BACKTESTING
from lumibot.credentials import broker
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies import Strategy
from lumibot.traders import Trader
# Out:
# 2024-12-11 23:45:00 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:00 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:01 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:01 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:02 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:02 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:03 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:03 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:03 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:03 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:04 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:04 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:04 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:04 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:04 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:04 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:06 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:06 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:06 | lumibot.credentials | WARNING | No .env file found. This is ok if you are using environment variables or secrets (like on Replit, AWS, etc), but if you are not, please create a .env file in the root directory of the project.
# 2024-12-11 23:45:06 | asyncio | INFO | [unknown] Waiting for the socket stream connection to be established,
#                 method _stream_established must be called
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:06 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | started trading stream
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from datetime import datetime
# ----> 2 from lumibot.credentials import IS_BACKTESTING
#       3 from lumibot.credentials import broker
#       4 from lumibot.backtesting import YahooDataBacktesting
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\credentials.py:204
#     201 else:
#     202     # If using Alpaca as a broker, set that as the broker
#     203     if ALPACA_CONFIG["API_KEY"]:
# --> 204         broker = Alpaca(ALPACA_CONFIG)
#     206     # If using Tradier as a broker, set that as the broker
#     207     elif TRADIER_CONFIG["ACCESS_TOKEN"]:
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\brokers\alpaca.py:130, in Alpaca.__init__(self, config, max_workers, chunk_size, connect_stream, data_source)
#     121     data_source = AlpacaData(config, max_workers=max_workers, chunk_size=chunk_size)
#     122 super().__init__(
#     123     name="alpaca",
#     124     connect_stream=connect_stream,
#    (...)
#     127     max_workers=max_workers,
#     128 )
# --> 130 self.api = TradingClient(self.api_key, self.api_secret, paper=self.is_paper)
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\client.py:74, in TradingClient.__init__(self, api_key, secret_key, oauth_token, paper, raw_data, url_override)
#      53 def __init__(
#      54     self,
#      55     api_key: Optional[str] = None,
#    (...)
#      60     url_override: Optional[str] = None,
#      61 ) -> None:
#      62     """
#      63     Instantiates a client for trading and managing personal brokerage accounts.
#      64
#    (...)
#      72         url_override (Optional[str]): If specified allows you to override the base url the client points to for proxy/testing.
#      73     """
# ---> 74     super().__init__(
#      75         api_key=api_key,
#      76         secret_key=secret_key,
#      77         oauth_token=oauth_token,
#      78         api_version="v2",
#      79         base_url=(
#      80             url_override
#      81             if url_override
#      82             else BaseURL.TRADING_PAPER if paper else BaseURL.TRADING_LIVE
#      83         ),
#      84         sandbox=paper,
#      85         raw_data=raw_data,
#      86     )
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\common\rest.py:61, in RESTClient.__init__(self, base_url, api_key, secret_key, oauth_token, use_basic_auth, api_version, sandbox, raw_data, retry_attempts, retry_wait_seconds, retry_exception_codes)
#      29 def __init__(
#      30     self,
#      31     base_url: Union[BaseURL, str],
#    (...)
#      41     retry_exception_codes: Optional[List[int]] = None,
#      42 ) -> None:
#      43     """Abstract base class for REST clients. Handles submitting HTTP requests to
#      44     Alpaca API endpoints.
#      45
#    (...)
#      58         retry_exception_codes (Optional[List[int]]): The API exception codes to retry a request on.
#      59     """
# ---> 61     self._api_key, self._secret_key, self._oauth_token = self._validate_credentials(
#      62         api_key=api_key, secret_key=secret_key, oauth_token=oauth_token
#      63     )
#      64     self._api_version: str = api_version
#      65     self._base_url: Union[BaseURL, str] = base_url
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\common\rest.py:362, in RESTClient._validate_credentials(api_key, secret_key, oauth_token)
#     357     raise ValueError(
#     358         "Either an oauth_token or an api_key may be supplied, but not both"
#     359     )
#     361 if not oauth_token and not (api_key and secret_key):
# --> 362     raise ValueError(
#     363         "A corresponding secret_key must be supplied with the api_key"
#     364     )
#     366 return api_key, secret_key, oauth_token
#
# ValueError: A corresponding secret_key must be supplied with the api_key
# 2024-12-11 23:45:06 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:07 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:07 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:07 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:07 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:07 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:07 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:08 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:08 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:09 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:09 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:09 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:09 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:09 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:10 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:10 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:10 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:10 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:11 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:11 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:11 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:11 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:12 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:12 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:12 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23:45:12 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:12 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:12 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:12 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:12 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:13 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:13 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:13 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:13 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:13 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:13 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:14 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:14 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:15 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:15 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:15 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:15 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:18 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:18 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:18 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:18 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:19 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:21 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:21 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:21 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:21 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:21 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:21 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:22 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:22 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:22 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:22 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:22 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:23 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:23 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:24 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:24 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:24 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:24 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:24 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:25 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:25 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:25 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:25 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:26 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:26 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:26 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:26 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:27 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:27 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:28 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:28 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:28 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:28 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:28 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:29 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23:45:29 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:29 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:29 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:31 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:31 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:31 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:31 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:31 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:32 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:32 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:32 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:32 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:32 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:32 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:34 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:34 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:34 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:34 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:35 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:35 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:35 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:35 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:35 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:35 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:35 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:35 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:36 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:36 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:37 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23:45:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:37 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:37 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:37 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:38 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:38 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:38 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:38 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:38 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:38 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:38 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:38 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:39 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:39 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:40 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23:45:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:41 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:41 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:41 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:41 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:41 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:41 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:43 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:45 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:45 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:45 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:45 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:48 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23:45:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:49 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:49 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:52 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:55 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:55 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:55 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:55 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:57 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:57 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:58 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:58 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:45:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:46:00 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:46:00 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-11 23:46:01 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-11 23:46:01 | alpaca.trading.stream | INFO | starting trading websocket connection
# ...
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:40 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:41 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:41 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:44 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:45 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:45 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:49 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:49 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:50 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:51 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:52 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:52 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:52 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:52 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:54 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:54 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2024-12-12 00:36:54 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2024-12-12 00:36:54 | alpaca.trading.stream | INFO | starting trading websocket connection
