# %%
from dotenv import load_dotenv
import os
load_dotenv()

API_KEY = os.getenv("ALPACA_API_KEY")
SECRET_KEY = os.getenv("ALPACA_SECRET_KEY")
BASE_URL = "https://paper-api.alpaca.markets"  # Use live URL if trading real money

if not API_KEY:
    raise ValueError("API_KEY must be supplied")
if not SECRET_KEY:
    raise ValueError("SECRET_KEY must be supplied")

from lumibot.brokers import Alpaca
# from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies.strategy import Strategy
from lumibot.traders import Trader
from datetime import datetime 
from alpaca_trade_api import REST 
from pandas import Timedelta 
from finbert_utils import estimate_sentiment

ALPACA_CREDS = {
    "API_KEY":API_KEY, 
    "API_SECRET": SECRET_KEY, 
    "PAPER": True
}
# Out:
# 2024-12-11 23:31:03 | lumibot.credentials | WARNING | No .env file found. This is ok if you are using environment variables or secrets (like on Replit, AWS, etc), but if you are not, please create a .env file in the root directory of the project.
# 2024-12-11 23:31:03 | asyncio | INFO | [unknown] Waiting for the socket stream connection to be established,
#                 method _stream_established must be called
# 2024-12-11 23:31:03 | alpaca.trading.stream | INFO | started trading stream
# 2024-12-11 23:31:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 16
#      14 from lumibot.brokers import Alpaca
#      15 # from lumibot.backtesting import YahooDataBacktesting
# ---> 16 from lumibot.strategies.strategy import Strategy
#      17 from lumibot.traders import Trader
#      18 from datetime import datetime
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\strategies\__init__.py:1
# ----> 1 from .strategy import Strategy
#       2 from .strategy_executor import StrategyExecutor
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\strategies\strategy.py:19
#      16 from ..tools import get_risk_free_rate
#      17 from ..traders import Trader
# ---> 19 from ._strategy import _Strategy
#      21 matplotlib.use("Agg")
#      23 class Strategy(_Strategy):
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\strategies\_strategy.py:24
#      21 from sqlalchemy import create_engine, inspect, text
#      23 import pandas as pd
# ---> 24 from ..backtesting import BacktestingBroker, PolygonDataBacktesting, ThetaDataBacktesting
#      25 from ..entities import Asset, Position, Order
#      26 from ..tools import (
#      27     create_tearsheet,
#      28     day_deduplicate,
#    (...)
#      33     to_datetime_aware,
#      34 )
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\backtesting\__init__.py:5
#       3 from .backtesting_broker import BacktestingBroker
#       4 from .pandas_backtesting import PandasDataBacktesting
# ----> 5 from .polygon_backtesting import PolygonDataBacktesting
#       6 from .thetadata_backtesting import ThetaDataBacktesting
#       7 from .yahoo_backtesting import YahooDataBacktesting
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\backtesting\polygon_backtesting.py:11
#       9 from lumibot.data_sources import PandasData
#      10 from lumibot.entities import Asset, Data
# ---> 11 from lumibot.tools import polygon_helper
#      12 from lumibot.tools.polygon_helper import PolygonClient
#      14 START_BUFFER = timedelta(days=5)
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\tools\polygon_helper.py:24
#      22 from lumibot.entities import Asset
#      23 from lumibot import LUMIBOT_DEFAULT_PYTZ
# ---> 24 from lumibot.credentials import POLYGON_API_KEY
#      26 MAX_POLYGON_DAYS = 30
#      28 # Define a cache dictionary to store schedules and a global dictionary for buffered schedules
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\credentials.py:204
#     201 else:
#     202     # If using Alpaca as a broker, set that as the broker
#     203     if ALPACA_CONFIG["API_KEY"]:
# --> 204         broker = Alpaca(ALPACA_CONFIG)
#     206     # If using Tradier as a broker, set that as the broker
#     207     elif TRADIER_CONFIG["ACCESS_TOKEN"]:
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\lumibot\brokers\alpaca.py:130, in Alpaca.__init__(self, config, max_workers, chunk_size, connect_stream, data_source)
#     121     data_source = AlpacaData(config, max_workers=max_workers, chunk_size=chunk_size)
#     122 super().__init__(
#     123     name="alpaca",
#     124     connect_stream=connect_stream,
#    (...)
#     127     max_workers=max_workers,
#     128 )
# --> 130 self.api = TradingClient(self.api_key, self.api_secret, paper=self.is_paper)
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\client.py:74, in TradingClient.__init__(self, api_key, secret_key, oauth_token, paper, raw_data, url_override)
#      53 def __init__(
#      54     self,
#      55     api_key: Optional[str] = None,
#    (...)
#      60     url_override: Optional[str] = None,
#      61 ) -> None:
#      62     """
#      63     Instantiates a client for trading and managing personal brokerage accounts.
#      64
#    (...)
#      72         url_override (Optional[str]): If specified allows you to override the base url the client points to for proxy/testing.
#      73     """
# ---> 74     super().__init__(
#      75         api_key=api_key,
#      76         secret_key=secret_key,
#      77         oauth_token=oauth_token,
#      78         api_version="v2",
#      79         base_url=(
#      80             url_override
#      81             if url_override
#      82             else BaseURL.TRADING_PAPER if paper else BaseURL.TRADING_LIVE
#      83         ),
#      84         sandbox=paper,
#      85         raw_data=raw_data,
#      86     )
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\common\rest.py:61, in RESTClient.__init__(self, base_url, api_key, secret_key, oauth_token, use_basic_auth, api_version, sandbox, raw_data, retry_attempts, retry_wait_seconds, retry_exception_codes)
#      29 def __init__(
#      30     self,
#      31     base_url: Union[BaseURL, str],
#    (...)
#      41     retry_exception_codes: Optional[List[int]] = None,
#      42 ) -> None:
#      43     """Abstract base class for REST clients. Handles submitting HTTP requests to
#      44     Alpaca API endpoints.
#      45
#    (...)
#      58         retry_exception_codes (Optional[List[int]]): The API exception codes to retry a request on.
#      59     """
# ---> 61     self._api_key, self._secret_key, self._oauth_token = self._validate_credentials(
#      62         api_key=api_key, secret_key=secret_key, oauth_token=oauth_token
#      63     )
#      64     self._api_version: str = api_version
#      65     self._base_url: Union[BaseURL, str] = base_url
#
# File c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\common\rest.py:362, in RESTClient._validate_credentials(api_key, secret_key, oauth_token)
#     357     raise ValueError(
#     358         "Either an oauth_token or an api_key may be supplied, but not both"
#     359     )
#     361 if not oauth_token and not (api_key and secret_key):
# --> 362     raise ValueError(
#     363         "A corresponding secret_key must be supplied with the api_key"
#     364     )
#     366 return api_key, secret_key, oauth_token
#
# ValueError: A corresponding secret_key must be supplied with the api_key
# 2024-12-11 23:31:06 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\chavv\anaconda\envs\stock-market\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2024-12-11 23